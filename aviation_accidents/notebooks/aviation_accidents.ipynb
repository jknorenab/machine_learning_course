# %% [markdown]
# ## Aviation Accidents and Incidents (NTSB, FAA, WAAS)

# %% [markdown]
# En el dataset que se encuentra [aquí](https://www.kaggle.com/datasets/prathamsharma123/aviation-accidents-and-incidents-ntsb-faa-waas) se puede encontrar la información registrada sobre distintos accidentes e incidentes ocurridos desde 1985 en aviones. La idea es describir los datos registrados y analizar cada una de las variables.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#la primera linea genera un path absoluto de la carpeta en la que estoy
PROJ_DIR = os.path.abspath(os.path.join(os.pardir))
print(PROJ_DIR)
# Out:
# /home/katherine/Documentos/Machine_Learning_Cristian_2022/Data_cleaning/repositorio/machine_learning_course/aviation_accidents

# %%
#la segunda linea une al path absoluto anterior, aldireccion data, raw, +el nombre del archivo
#que estamos asumiento ya está en la dirección data/raw
file_name = 'airline_accidents.csv'
#aquí entonces tenemos un nuevo path absoluto que va a funcionar
#sin importar si la persona lo usa en windows, en ubuntu, lo que facilita la migración
data_name = os.path.join(PROJ_DIR, 'data', 'raw', file_name)
#Hicimos una investigación con valores únicos para poder ver cómo aparecían los nulos. (na_values)
#Luego, podemos ver la columna que tiene fechas y decirle que lo guarde en formato fecha, (parse_dates)
#tambien podemos elegir cuantas filas tomar (nrows) sin embargo esto no es tan bueno porque los datos podrían estar ordenados
#nrows toma siempre los primeros valores seleccionads ( 25000, 30000)
#en ese caso lo mejor es cargar todos los datos y luego tomar una submuestra para el análisis
#cuando sabemos que hay una variable única sobre la cual podemos indexar ( que no sea como en excel) usando, index = 'Event ID'
df = pd.read_csv(data_name, na_values= ['  '], parse_dates = ['Event Date'])
#la submuestra se puede hacer como
#df= df.sample[25000]
# lo mejor sería volver a correr esta celda para que cambie aleatoriamente la submuestra y ver si la gráfica cambia

# %% [markdown]
# Nos sale un error: /tmp/ipykernel_8198/4275079040.py:7: DtypeWarning: Columns (0,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_name)
# Este error nos está diciendo que el va a asumir que todas las entradas son de tipo objeto porque no sé como clasificarlas, pero eso consume mucha memoria. Entonces si queremos resolver el problema de fondo hay que entender porqué está volviendo todos de tipo objeto y consumiendo memoria. La cosa es que el me dice que para resolverlo debo poner low_memory = False, y esto nunca es lo mejor. Porque le estamos diciendo que consuma toda la memoria que quiera y pues no mi ciela.

# %%
df.head()
# Out:
#           Event Id Investigation Type Accident Number Event Date  \
# 0  20080125X00106           Accident      SEA08CA056  2007-12-31
# 1  20080206X00141           Accident      CHI08WA075  2007-12-31
# 2  20080129X00122           Accident      CHI08CA057  2007-12-30
# 3  20080114X00045           Accident      LAX08FA043  2007-12-30
# 4  20080109X00032           Accident      NYC08FA071  2007-12-30
#
#                      Location           Country   Latitude   Longitude  \
# 0              Santa Ana, CA     United States   33.675556 -117.868056
# 1   Guernsey, United Kingdom    United Kingdom   49.435000   -2.600278
# 2             Alexandria, MN     United States   45.866111  -95.394444
# 3            Paso Robles, CA     United States   35.542222 -120.522778
# 4               Cherokee, AL     United States   34.688611  -87.920000
#
#   Airport Code                  Airport Name  ... Purpose of Flight  \
# 0         SNA    John Wayne - Orange County   ...    Instructional
# 1          NaN                           NaN  ...          Unknown
# 2         AXN        Chandler Field Airport   ...         Personal
# 3         PRB           Paso Robles Airport   ...         Personal
# 4          NaN                           NaN  ...   Other Work Use
#
#   Air Carrier Total Fatal Injuries Total Serious Injuries  \
# 0         NaN                  NaN                    NaN
# 1         NaN                  NaN                    NaN
# 2         NaN                  NaN                    NaN
# 3         NaN                  1.0                    NaN
# 4         NaN                  3.0                    0.0
#
#   Total Minor Injuries Total Uninjured Weather Condition  \
# 0                  NaN             2.0              VMC
# 1                  NaN             1.0               NaN
# 2                  NaN             1.0              VMC
# 3                  NaN             NaN              VMC
# 4                  0.0             0.0              VMC
#
#    Broad Phase of Flight Report Publication Date Unnamed: 30
# 0               LANDING              02/28/2008
# 1                    NaN             02/06/2008
# 2               TAKEOFF              02/28/2008
# 3           MANEUVERING              06/20/2014
# 4           MANEUVERING              01/15/2009
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Event Id                 25000 non-null  object
#  1   Investigation Type       25000 non-null  object
#  2   Accident Number          25000 non-null  object
#  3   Event Date               25000 non-null  datetime64[ns]
#  4   Location                 24963 non-null  object
#  5   Country                  24874 non-null  object
#  6   Latitude                 11964 non-null  float64
#  7   Longitude                11954 non-null  float64
#  8   Airport Code             14505 non-null  object
#  9   Airport Name             15022 non-null  object
#  10  Injury Severity          25000 non-null  object
#  11  Aircraft Damage          24225 non-null  object
#  12  Aircraft Category        4038 non-null   object
#  13  Registration Number      23769 non-null  object
#  14  Make                     24986 non-null  object
#  15  Model                    24983 non-null  object
#  16  Amateur Built            24899 non-null  object
#  17  Number of Engines        23005 non-null  float64
#  18  Engine Type              23552 non-null  object
#  19  FAR Description          4044 non-null   object
#  20  Schedule                 3591 non-null   object
#  21  Purpose of Flight        23340 non-null  object
#  22  Air Carrier              993 non-null    object
#  23  Total Fatal Injuries     13786 non-null  float64
#  24  Total Serious Injuries   12739 non-null  float64
#  25  Total Minor Injuries     13318 non-null  float64
#  26  Total Uninjured          19256 non-null  float64
#  27  Weather Condition        24495 non-null  object
#  28  Broad Phase of Flight    23326 non-null  object
#  29  Report Publication Date  24714 non-null  object
#  30  Unnamed: 30              25000 non-null  object
# dtypes: datetime64[ns](1), float64(7), object(23)
# memory usage: 5.9+ MB

# %%
#hacemos esta investigación para identificar cómo se expresan los valores nulos
#lo mejor es tomar una columna que tengamos muchos nulos o que pueda tomar pocos valores
df['Investigation Type'].unique()
# Out:
# array([' Accident ', ' Incident ', nan], dtype=object)

# %%
df['Investigation Type'].unique()
# Out:
# array([' Accident ', ' Incident ', nan], dtype=object)

# %% [markdown]
# ### Análisis estadístico numérico

# %% [markdown]
# En esta parte del proyecto, se busca entender más las características asociadas a las variables, como las medidas de tendencia central y de dispersión, los valores atípicos y los tipos de las variables (categóricas nominales u ordinales, numéricas continuas o discretas). Además se recomienda hacer un análisis temporal de los datos.

# %%
df['Location'].nunique()
# Out:
# 11876

# %%
df['Country'].nunique()
# Out:
# 142

# %%
df['Total Fatal Injuries'].describe()
# Out:
# count    13786.000000
# mean         1.312636
# std          9.389189
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max        349.000000
# Name: Total Fatal Injuries, dtype: float64

# %%
df['Total Serious Injuries'].describe()
# Out:
# count    12739.000000
# mean         0.432059
# std          1.638224
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max         59.000000
# Name: Total Serious Injuries, dtype: float64

# %%
#vemos que tienen espacios al principio y al final
df['Investigation Type'].unique()
# Out:
# array([' Accident ', ' Incident '], dtype=object)

# %%
#lo que estabamos haciendo arriba a mano, lo podemos hacer con la función df.describe 
df.describe(datetime_is_numeric=True)
# Out:
#                        Event Date      Latitude     Longitude  \
# count                       25000  11964.000000  11954.000000
# mean   2001-11-09 02:48:52.992000     38.123677    -97.430118
# min           1996-01-04 00:00:00    -78.016945   -174.296666
# 25%           1998-10-26 00:00:00     33.439305   -116.226945
# 50%           2001-08-31 00:00:00     38.149445    -95.518194
# 75%           2004-10-15 00:00:00     42.548889    -82.028958
# max           2007-12-31 00:00:00     89.218056    177.557778
# std                           NaN     11.239502     31.905452
#
#        Number of Engines  Total Fatal Injuries  Total Serious Injuries  \
# count       23005.000000          13786.000000            12739.000000
# mean            1.151706              1.312636                0.432059
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              1.000000                1.000000
# max             4.000000            349.000000               59.000000
# std             0.434881              9.389189                1.638224
#
#        Total Minor Injuries  Total Uninjured
# count          13318.000000     19256.000000
# mean               0.702208         6.979435
# min                0.000000         0.000000
# 25%                0.000000         1.000000
# 50%                0.000000         1.000000
# 75%                1.000000         2.000000
# max              380.000000       699.000000
# std                4.519612        32.486646

# %%
df.describe(datetime_is_numeric=False, exclude = np.number)
# Out:
# /tmp/ipykernel_12873/226678195.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(datetime_is_numeric=False, exclude = np.number)
#                Event Id Investigation Type Accident Number  \
# count             25000              25000           25000
# unique            24655                  2           25000
# top     20001212X19172           Accident      SEA08CA056
# freq                  3              24088               1
# first               NaN                NaN             NaN
# last                NaN                NaN             NaN
#
#                  Event Date         Location          Country Airport Code  \
# count                 25000            24963            24874        14505
# unique                 4336            11876              142         4957
# top     2000-07-08 00:00:00   ANCHORAGE, AK    United States         NONE
# freq                     25              100            23189          439
# first   1996-01-04 00:00:00              NaN              NaN          NaN
# last    2007-12-31 00:00:00              NaN              NaN          NaN
#
#        Airport Name Injury Severity Aircraft Damage  ... Amateur Built  \
# count         15022           25000           24225  ...         24899
# unique         9452              82               3  ...             2
# top            N/A       Non-Fatal     Substantial   ...           No
# freq             65           18911           18256  ...         22162
# first           NaN             NaN             NaN  ...           NaN
# last            NaN             NaN             NaN  ...           NaN
#
#             Engine Type              FAR Description Schedule  \
# count             23552                         4044     3591
# unique                7                           14        3
# top      Reciprocating    Part 91: General Aviation     NSCH
# freq              19349                         3350     1343
# first               NaN                          NaN      NaN
# last                NaN                          NaN      NaN
#
#        Purpose of Flight                 Air Carrier Weather Condition  \
# count              23340                         993             24495
# unique                22                         823                 3
# top            Personal    (DBA: AMERICAN AIRLINES)               VMC
# freq               13983                           8             22445
# first                NaN                         NaN               NaN
# last                 NaN                         NaN               NaN
#
#        Broad Phase of Flight Report Publication Date Unnamed: 30
# count                  23326                   24714       25000
# unique                    12                    1411           1
# top                 LANDING              11/25/2003
# freq                    6290                     396       25000
# first                    NaN                     NaN         NaN
# last                     NaN                     NaN         NaN
#
# [6 rows x 24 columns]

# %%
#esto es lo mismo que la primera gráfica de 
df.describe(datetime_is_numeric=False, exclude = 'object')
# Out:
# /tmp/ipykernel_12873/3924874268.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(datetime_is_numeric=False, exclude = 'object')
#                  Event Date      Latitude     Longitude  Number of Engines  \
# count                 25000  11964.000000  11954.000000       23005.000000
# unique                 4336           NaN           NaN                NaN
# top     2000-07-08 00:00:00           NaN           NaN                NaN
# freq                     25           NaN           NaN                NaN
# first   1996-01-04 00:00:00           NaN           NaN                NaN
# last    2007-12-31 00:00:00           NaN           NaN                NaN
# mean                    NaN     38.123677    -97.430118           1.151706
# std                     NaN     11.239502     31.905452           0.434881
# min                     NaN    -78.016945   -174.296666           0.000000
# 25%                     NaN     33.439305   -116.226945           1.000000
# 50%                     NaN     38.149445    -95.518194           1.000000
# 75%                     NaN     42.548889    -82.028958           1.000000
# max                     NaN     89.218056    177.557778           4.000000
#
#         Total Fatal Injuries  Total Serious Injuries  Total Minor Injuries  \
# count           13786.000000            12739.000000          13318.000000
# unique                   NaN                     NaN                   NaN
# top                      NaN                     NaN                   NaN
# freq                     NaN                     NaN                   NaN
# first                    NaN                     NaN                   NaN
# last                     NaN                     NaN                   NaN
# mean                1.312636                0.432059              0.702208
# std                 9.389189                1.638224              4.519612
# min                 0.000000                0.000000              0.000000
# 25%                 0.000000                0.000000              0.000000
# 50%                 0.000000                0.000000              0.000000
# 75%                 1.000000                1.000000              1.000000
# max               349.000000               59.000000            380.000000
#
#         Total Uninjured
# count      19256.000000
# unique              NaN
# top                 NaN
# freq                NaN
# first               NaN
# last                NaN
# mean           6.979435
# std           32.486646
# min            0.000000
# 25%            1.000000
# 50%            1.000000
# 75%            2.000000
# max          699.000000

# %%
df.describe(include ='O')
# Out:
#                Event Id Investigation Type Accident Number         Location  \
# count             25000              25000           25000            24963
# unique            24655                  2           25000            11876
# top     20001212X19172           Accident      SEA08CA056    ANCHORAGE, AK
# freq                  3              24088               1              100
#
#                 Country Airport Code Airport Name Injury Severity  \
# count             24874        14505        15022           25000
# unique              142         4957         9452              82
# top      United States         NONE          N/A       Non-Fatal
# freq              23189          439           65           18911
#
#        Aircraft Damage Aircraft Category  ... Amateur Built      Engine Type  \
# count            24225              4038  ...         24899            23552
# unique               3                 8  ...             2                7
# top       Substantial          Airplane   ...           No    Reciprocating
# freq             18256              3419  ...         22162            19349
#
#                     FAR Description Schedule Purpose of Flight  \
# count                          4044     3591             23340
# unique                           14        3                22
# top      Part 91: General Aviation     NSCH          Personal
# freq                           3350     1343             13983
#
#                        Air Carrier Weather Condition Broad Phase of Flight  \
# count                          993             24495                 23326
# unique                         823                 3                    12
# top      (DBA: AMERICAN AIRLINES)               VMC               LANDING
# freq                             8             22445                  6290
#
#        Report Publication Date Unnamed: 30
# count                    24714       25000
# unique                    1411           1
# top                11/25/2003
# freq                       396       25000
#
# [4 rows x 23 columns]

# %%
df['Aircraft Damage'].unique()
# Out:
# array([' Substantial ', ' Minor ', ' Destroyed ', nan], dtype=object)

# %%
df['Aircraft Category'].unique()
# Out:
# array([' Airplane ', nan, ' Helicopter ', ' Gyrocraft ', ' Ultralight ',
#        ' Powered-Lift ', ' Glider ', ' Balloon ', ' Blimp '], dtype=object)

# %%
#aquí lo podemos poner como un true / false
df['Amateur Built'].unique()
# Out:
# array([' No ', ' Yes ', nan], dtype=object)

# %%
df['Engine Type'].unique()
# Out:
# array([' Reciprocating ', nan, ' Turbo Shaft ', ' Turbo Fan ',
#        ' Turbo Jet ', ' Turbo Prop ', ' Unknown ', ' REC, TJ, TJ '],
#       dtype=object)

# %%
#al modelo no le podemos pasar una lista de tipos de variable, porque al modelo se le deben pasar números
#por eso planteamos hacer un OneHotEncoder, pero se crecen un montón las columnas, entoncs podemos ver si vale la pena
#para eso veamos la cantidad de valores
df['Purpose of Flight'].unique()
# Out:
# array([' Instructional ', ' Unknown ', ' Personal ', ' Other Work Use ',
#        nan, ' Public Aircraft - Federal ', ' Business ', ' Ferry ',
#        ' Aerial Application ', ' Public Aircraft - State ',
#        ' Positioning ', ' Executive/Corporate ', ' Aerial Observation ',
#        ' Banner Tow ', ' External Load ', ' Flight Test ',
#        ' Public Aircraft - Local ', ' Air Race/Show ', ' Glider Tow ',
#        ' Public Aircraft ', ' Skydiving ', ' Firefighting ', ' Air Drop '],
#       dtype=object)

# %%
df['Purpose of Flight'].value_counts()
# Out:
#  Personal                      13983
#  Instructional                  3113
#  Unknown                        1791
#  Aerial Application             1218
#  Business                        879
#  Positioning                     683
#  Other Work Use                  435
#  Public Aircraft                 344
#  Aerial Observation              188
#  Ferry                           186
#  Flight Test                     151
#  Executive/Corporate             139
#  Air Race/Show                    59
#  Skydiving                        52
#  Public Aircraft - Federal        28
#  Banner Tow                       25
#  External Load                    19
#  Public Aircraft - State          15
#  Glider Tow                       11
#  Public Aircraft - Local          10
#  Firefighting                      7
#  Air Drop                          4
# Name: Purpose of Flight, dtype: int64

# %%
#Podemos normalizarla para entender las relaciones
df['Purpose of Flight'].value_counts(normalize = True, dropna =False)*100
# Out:
#  Personal                      55.932
#  Instructional                 12.452
#  Unknown                        7.164
# NaN                             6.640
#  Aerial Application             4.872
#  Business                       3.516
#  Positioning                    2.732
#  Other Work Use                 1.740
#  Public Aircraft                1.376
#  Aerial Observation             0.752
#  Ferry                          0.744
#  Flight Test                    0.604
#  Executive/Corporate            0.556
#  Air Race/Show                  0.236
#  Skydiving                      0.208
#  Public Aircraft - Federal      0.112
#  Banner Tow                     0.100
#  External Load                  0.076
#  Public Aircraft - State        0.060
#  Glider Tow                     0.044
#  Public Aircraft - Local        0.040
#  Firefighting                   0.028
#  Air Drop                       0.016
# Name: Purpose of Flight, dtype: float64

# %% [markdown]
# ## Tareala tarea es revisar una forma para tener menos categorías en la ultima categoría.
# Para el análisis univariado debemos hacer los gráficos, histogramas, boxplot, violinplot.
# No tiene que ser para todas.
# esto se llama exploratory data analysis. EDA (entendimiento de los datos)
# resolver el error de sección individual

# %% [markdown]
# ### Análisis univariado

# %% [markdown]
# En esta sección, se busca encontrar relaciones de las variables a nivel univariado, teniendo en cuenta tendencias de acuerdo al comportamiento de las variables separadas por categorías.

# %% [markdown]
# ### Análisis multivariado

# %% [markdown]
# En esta sección, se busca entender un poco más la correlación entre las variables, y la distribución entre las variables para conocer si existen relaciones entre ellas. Se puede hacer análisis de tipo bivariado o de más variables, de acuerdo al tipo de variables y de los objetivos que se persiguen (comparativos, de composición, de distribución).

# %% [markdown]
# ## Sección de trabajo individual

# %% [markdown]
# En esta parte, se propone revisar alguna otra de las bases para realizar el respectivo análisis y limpieza. La idea es comprender muy bien los datos para dar un pequeño informe oral sobre los resultados obtenidos.

# %%
file_name = 'ntsb_aviation_data.csv'
data_name = os.path.join(PROJ_DIR, 'data', 'raw', file_name)
df = pd.read_csv(data_name)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [44], in <cell line: 3>()
#       1 file_name = 'ntsb_aviation_data.csv'
#       2 data_name = os.path.join(PROJ_DIR, 'data', 'raw', file_name)
# ----> 3 df = pd.read_csv(data_name)
#
# File ~/anaconda3/envs/income_clasification/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/income_clasification/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/income_clasification/lib/python3.9/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~/anaconda3/envs/income_clasification/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1250, in TextFileReader.read(self, nrows)
#    1248 nrows = validate_integer("nrows", nrows)
#    1249 try:
# -> 1250     index, columns, col_dict = self._engine.read(nrows)
#    1251 except Exception:
#    1252     self.close()
#
# File ~/anaconda3/envs/income_clasification/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~/anaconda3/envs/income_clasification/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/anaconda3/envs/income_clasification/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/anaconda3/envs/income_clasification/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/anaconda3/envs/income_clasification/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc9 in position 108582: invalid continuation byte

# %%
df.head()
